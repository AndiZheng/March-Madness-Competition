# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('NCAA.csv')

# %%
df.head()
# Out:
#    team1_id  team1_score  team2_id  team2_score  team1_seed  team2_seed  \
# 0      1373           81      1108           77          16          16
# 1      1104           86      1194           78           2          15
# 2      1112           86      1364           81           3          14
# 3      1181           84      1457           37           1          16
# 4      1231           75      1428           56           5          12
#
#    team1_dis(km)  team2_dis(km)  team1_pt_school_ncaa  team1_pt_overall_ncaa  \
# 0     932.116689    1076.682624                     0                      0
# 1     969.775258    1058.567916                     0                      2
# 2     513.529264    1210.852647                    17                     22
# 3     148.384590     339.990955                    17                     17
# 4    3007.304604     859.001991                     1                      1
#
# ...

# %%
l1 = df.columns.values.tolist()
l1
# Out:
# ['team1_id',
#  'team1_score',
#  'team2_id',
#  'team2_score',
#  'team1_seed',
#  'team2_seed',
#  'team1_dis(km)',
#  'team2_dis(km)',
#  'team1_pt_school_ncaa',
#  'team1_pt_overall_ncaa',
#  'team1_pt_school_s16',
#  'team1_pt_overall_s16',
#  'team1_pt_school_ff',
#  'team1_pt_overall_ff',
#  'team1_pt_career_school_wins',
#  'team1_pt_career_school_losses',
#  'team1_pt_career_overall_wins',
#  'team1_pt_career_overall_losses',
#  'team1_pt_team_season_wins',
#  'team1_pt_team_season_losses',
#  'team1_pt_coach_season_wins',
#  'team1_pt_coach_season_losses',
#  'team2_pt_school_ncaa',
#  'team2_pt_overall_ncaa',
#  'team2_pt_school_s16',
#  'team2_pt_overall_s16',
#  'team2_pt_school_ff',
#  'team2_pt_overall_ff',
#  'team2_pt_career_school_wins',
#  'team2_pt_career_school_losses',
#  'team2_pt_career_overall_wins',
#  'team2_pt_career_overall_losses',
#  'team2_pt_team_season_wins',
#  'team2_pt_team_season_losses',
#  'team2_pt_coach_season_wins',
# ...

# %%
s1 = ','.join(l1)
s1
# Out:
# 'team1_id,team1_score,team2_id,team2_score,team1_seed,team2_seed,team1_dis(km),team2_dis(km),team1_pt_school_ncaa,team1_pt_overall_ncaa,team1_pt_school_s16,team1_pt_overall_s16,team1_pt_school_ff,team1_pt_overall_ff,team1_pt_career_school_wins,team1_pt_career_school_losses,team1_pt_career_overall_wins,team1_pt_career_overall_losses,team1_pt_team_season_wins,team1_pt_team_season_losses,team1_pt_coach_season_wins,team1_pt_coach_season_losses,team2_pt_school_ncaa,team2_pt_overall_ncaa,team2_pt_school_s16,team2_pt_overall_s16,team2_pt_school_ff,team2_pt_overall_ff,team2_pt_career_school_wins,team2_pt_career_school_losses,team2_pt_career_overall_wins,team2_pt_career_overall_losses,team2_pt_team_season_wins,team2_pt_team_season_losses,team2_pt_coach_season_wins,team2_pt_coach_season_losses,team1_fg2pct,team1_fg3pct,team1_ftpct,team1_blockpct,team1_oppfg2pct,team1_oppfg3pct,team1_oppftpct,team1_oppblockpct,team1_f3grate,team1_oppf3grate,team1_arate,team1_opparate,team1_stlrate,team1_oppstlr
# ...

# %%
import random
fileName = r'C:\Users\AndyZ\OneDrive\Desktop\March Madness\NCAA.csv'
newfile = r'C:\Users\AndyZ\OneDrive\Desktop\March Madness\shuffle.csv'
with open(fileName, 'r', encoding = 'utf-8') as f1, open(newfile,'w', encoding = 'utf-8') as f2:
    f2.write(s1+'\n')
    line = f1.readline().replace('\n','')
    lineList = line.split(',')
    team1 = []
    team2 = []
    for name in lineList:
        if name.startswith('team1'):
            i1 = lineList.index(name)
            team1.append(i1)
        if name.startswith('team2'):
            i2 = lineList.index(name)
            team2.append(i2)

    line = f1.readline().replace('\n','')
    while line != '':
        randomInt = random.randint(0,1)
        if randomInt == 1:
            f2.write(line+'\n')           
        if randomInt == 0:
            l1 = line.split(',')
            length = len(l1)
            for data in range(0,length):
                dataIndex = data
                if dataIndex in team1:
                    team1DataIndex = dataIndex
                    team2DataIndex = team2[team1.index(dataIndex)]
                    l1[team1DataIndex],l1[team2DataIndex] = l1[team2DataIndex],l1[team1DataIndex]
                else:
                    pass
            newstr = ','.join(l1)
            f2.write(newstr+'\n')
        line = f1.readline().replace('\n','')
